# %%
import pandas as pd
import json

# %%
with open('posts.json') as json_file:  
    data = json.load(json_file)

# %%
df_locs = pd.read_json("posts.json")
df_locs
# Out:
#     active  admin_level       airports  country_id  \
# 0        Y            4            MAS         956
# 1        Y            4       TUB, RUR         264
# 2        Y            4            CBR         917
# 3        Y            4            APW         977
# 4        Y            4            TRW         944
# 5        Y            4            BUA         956
# 6        Y            4            CHT          44
# 7        Y            4            NOU         264
# 8        Y            4            TKK         933
# 9        Y            4            ZLO         264
# 10       Y            4       NAN, SUV         934
# 11       Y            4            RAR         925
# 12       Y            4            CNS         917
# 13       Y            4            MMD         943
# 14       Y            4            GMR         976
# 15       Y            4            IPQ         921
# 16       Y            4       NAN, SUV         934
# ...

# %%
Eu_countries = ["Austria","Belgium","Bulgaria","Croatia","Cyprus","Czech Republic","Denmark","Estonia","Finland","France","Germany","Greece","Hungary","Ireland","Italy","Latvia","Lithuania","Luxembourg","Malta","Netherlands","Poland","Portugal","Romania","Slovakia","Slovenia","Spain","Sweden","United Kingdom"]
Eu_countries
# Out:
# ['Austria',
#  'Belgium',
#  'Bulgaria',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Ireland',
#  'Italy',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Netherlands',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'United Kingdom']

# %%
# for index, row in df.iterrows():
#     if row['country_name'] > 0:
#         df_locs.drop(index, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c420ab1e3517> in <module>
# ----> 1 for index, row in df.iterrows():
#       2     if row['country_name'] > 0:
#       3         df.drop(index, inplace=True)
#
# NameError: name 'df' is not defined

# %%
df_locs = df_locs[df_locs.country_name.isin(Eu_countries)]
df_locs_final = df_locs.filter(["country_id","country_name","id","location_name","lat","lon","region_name"])
df_locs_final=df_locs_final.rename(columns={"id":"location_id"})
df_locs_final
# Out:
#      country_id    country_name  location_id  \
# 1           264          France            2
# 7           264          France            8
# 9           264          France           10
# 14          976  United Kingdom           15
# 18          264          France           19
# 21          976  United Kingdom           22
# 32          264          France           33
# 33          264          France           34
# 40          264          France           41
# 48          976  United Kingdom           50
# 55          976  United Kingdom           57
# 64          264          France           66
# 73          264          France           75
# 78          264          France           80
# 136         264          France          138
# 165         264          France          169
# 175         976  United Kingdom          179
# 177         301     Netherlands          181
# 182         301     Netherlands          186
# 183         976  United Kingdom          187
# ...

# %%
df_locs_final.to_csv("Europe_list_locations.csv")
