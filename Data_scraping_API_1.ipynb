# %%
from bs4 import BeautifulSoup
import requests
import os
import pandas as pd
import requests
import json

# %%
url= "https://mtp.travel/api/rankings/users?checklistType=locations&gender=&country=United+States&country_id=977&vfIcg=&location=All+States%2FProvinces&location_id=all&ageGroup=&facebookConnected=&country_has_children=true&page="

# %%
MTP_df_final = pd.DataFrame()
for i in range(1,40):
    query_url = url+"i"
    MTP_response = requests.get(query_url)
    MTP_json = MTP_response.json()
    MTP_data =MTP_json["users"]["data"]
    # location_data = MTP_json["users"]["data"]["location"]
    # MTP_data
    MTP_df = pd.DataFrame(MTP_data)
    # MTP_df_final = MTP_df["first_name","last_name","birthday","location"]
    MTP_df_final = MTP_df_final.append(MTP_df.filter(["id","full_name", "birthday","gender","location"], axis=1))
    
MTP_df_final
# Out:
#        id                      full_name    birthday gender  \
# 0    3218              Robert A. Bonifas  1937-06-04      M
# 1    3533            Donald M Parrish Jr  1944-10-27      M
# 2       1                Charles A Veley  1965-06-25      M
# 3      53                  Bill Altaffer  1943-07-17      M
# 4    1125  Jagannathan Srinivasaraghavan  1950-05-13      M
# 5    1189                   Bart Hackley  1944-10-01      M
# 6    8149                   Frank Rainer  1943-05-08      M
# 7    2770               Larry Leventhal*  1935-05-25      M
# 8   19571                  Dominik Grzyb  1973-06-23      M
# 9   12131                      Bob Parda  1946-01-05      M
# 10     56            Alexander Gushansky  1937-05-23      M
# 11   5581                Joseph Krawczyk  1961-06-01      M
# 12  15222             John F. Burke, Jr.  1937-03-25      M
# 13  41231                 Steve Newcomer  1957-11-16      M
# 14  12163               Carmen Mccormick  1968-08-29      F
# 15    597             Alan K. Hogenauer*  1941-09-17      M
# 16    164                Robert Ippolito  1946-12-30      M
# 17  32394           Michael Chalmer Dunn  1949-03-31      M
# 18   6329                  Robert Petrik  1940-01-17      M
# 19     98              Carolyn Broadwell  1931-12-13      F
# 20    328               Christine Kloner  1963-07-11      F
# 21     32                    Tim Carlson  1938-02-09      M
# 22   1589                      Ray Woods  1942-02-28      M
# 23    111                 Michael Novins  1964-03-20      M
# 24   5186                    Ed Reynolds  1935-08-05      M
# 25   2759                Valentin Sazhin  1959-09-23      M
# 26   5544                 Joel Baumbaugh  1950-07-09      M
# 27    317                Lynn Stephenson  1926-11-15      F
# 28    524                   Steve Fuller  1948-07-12      M
# 29   7411                    Robert Amon  1940-09-24      M
# ..    ...                            ...         ...    ...
# 20    328               Christine Kloner  1963-07-11      F
# 21     32                    Tim Carlson  1938-02-09      M
# 22   1589                      Ray Woods  1942-02-28      M
# 23    111                 Michael Novins  1964-03-20      M
# 24   5186                    Ed Reynolds  1935-08-05      M
# 25   2759                Valentin Sazhin  1959-09-23      M
# 26   5544                 Joel Baumbaugh  1950-07-09      M
# 27    317                Lynn Stephenson  1926-11-15      F
# 28    524                   Steve Fuller  1948-07-12      M
# 29   7411                    Robert Amon  1940-09-24      M
# 30   8066             Magali V. Hinojosa  1950-11-10      F
# 31  24615                      Tim Meyer  1955-05-29      M
# 32     23                    Ted Cookson  1951-05-29      M
# 33   2153                 Richard Pazara  1946-09-25      M
# 34  12614                 Frank Robinson  1942-10-23      M
# 35  14140                   Sevi Ceviche  1976-02-29      M
# 36  11033                  Meredith Amon  1940-07-11      F
# 37   1483                     Jim Fenton  1931-01-10      M
# 38   4490                   Jack Wheeler  1943-11-09      M
# 39   6125                  Cathy Lincoln  1956-07-17      F
# 40  41540                  David Hoffman  1954-10-20      M
# 41  31809           Gene (terry) Johnson  1948-12-11      M
# 42   4051                       Ken Shin  1934-08-30      M
# 43   1555                   Hugh Randall  1942-09-18      M
# 44   4390                  Lee Abbamonte  1978-08-29      M
# 45  29470                Harold Griffith  1932-12-15      M
# 46   3774                 Gloria Helmuth  1940-11-16      F
# 47   3271                   William Ball  1959-08-25      M
# 48  10387              William Humphries  1932-01-25      M
# 49  24006           Charles D. Williams*  1926-03-02      M
#
#                                              location
# 0   {'id': 98, 'Location': 'Illinois', 'RegionIDne...
# 1   {'id': 98, 'Location': 'Illinois', 'RegionIDne...
# 2   {'id': 89, 'Location': 'California', 'RegionID...
# 3   {'id': 89, 'Location': 'California', 'RegionID...
# 4   {'id': 98, 'Location': 'Illinois', 'RegionIDne...
# 5   {'id': 89, 'Location': 'California', 'RegionID...
# 6   {'id': 89, 'Location': 'California', 'RegionID...
# 7   {'id': 121, 'Location': 'New York', 'RegionIDn...
# 8   {'id': 150, 'Location': 'Wisconsin', 'RegionID...
# 9   {'id': 89, 'Location': 'California', 'RegionID...
# 10  {'id': 89, 'Location': 'California', 'RegionID...
# 11  {'id': 83, 'Location': 'Alabama', 'RegionIDnew...
# 12  {'id': 128, 'Location': 'Ohio', 'RegionIDnew':...
# 13  {'id': 89, 'Location': 'California', 'RegionID...
# 14  {'id': 89, 'Location': 'California', 'RegionID...
# 15  {'id': 89, 'Location': 'California', 'RegionID...
# 16  {'id': 123, 'Location': 'North Carolina', 'Reg...
# 17  {'id': 98, 'Location': 'Illinois', 'RegionIDne...
# 18  {'id': 95, 'Location': 'Florida', 'RegionIDnew...
# 19  {'id': 89, 'Location': 'California', 'RegionID...
# 20  {'id': 121, 'Location': 'New York', 'RegionIDn...
# 21  {'id': 89, 'Location': 'California', 'RegionID...
# 22  {'id': 101, 'Location': 'Kansas', 'RegionIDnew...
# 23  {'id': 121, 'Location': 'New York', 'RegionIDn...
# 24  {'id': 89, 'Location': 'California', 'RegionID...
# 25  {'id': 121, 'Location': 'New York', 'RegionIDn...
# 26  {'id': 89, 'Location': 'California', 'RegionID...
# 27  {'id': 123, 'Location': 'North Carolina', 'Reg...
# 28  {'id': 113, 'Location': 'Missouri', 'RegionIDn...
# 29  {'id': 131, 'Location': 'Oregon', 'RegionIDnew...
# ..                                                ...
# 20  {'id': 121, 'Location': 'New York', 'RegionIDn...
# 21  {'id': 89, 'Location': 'California', 'RegionID...
# 22  {'id': 101, 'Location': 'Kansas', 'RegionIDnew...
# 23  {'id': 121, 'Location': 'New York', 'RegionIDn...
# 24  {'id': 89, 'Location': 'California', 'RegionID...
# 25  {'id': 121, 'Location': 'New York', 'RegionIDn...
# 26  {'id': 89, 'Location': 'California', 'RegionID...
# 27  {'id': 123, 'Location': 'North Carolina', 'Reg...
# 28  {'id': 113, 'Location': 'Missouri', 'RegionIDn...
# 29  {'id': 131, 'Location': 'Oregon', 'RegionIDnew...
# 30  {'id': 143, 'Location': 'Texas', 'RegionIDnew'...
# 31  {'id': 116, 'Location': 'Nevada', 'RegionIDnew...
# 32  {'id': 95, 'Location': 'Florida', 'RegionIDnew...
# 33  {'id': 143, 'Location': 'Texas', 'RegionIDnew'...
# 34  {'id': 89, 'Location': 'California', 'RegionID...
# 35  {'id': 104, 'Location': 'Louisiana', 'RegionID...
# 36  {'id': 131, 'Location': 'Oregon', 'RegionIDnew...
# 37  {'id': 89, 'Location': 'California', 'RegionID...
# 38  {'id': 94, 'Location': 'District of Columbia',...
# 39  {'id': 128, 'Location': 'Ohio', 'RegionIDnew':...
# 40  {'id': 143, 'Location': 'Texas', 'RegionIDnew'...
# 41  {'id': 107, 'Location': 'Maryland', 'RegionIDn...
# 42  {'id': 89, 'Location': 'California', 'RegionID...
# 43  {'id': 95, 'Location': 'Florida', 'RegionIDnew...
# 44  {'id': 121, 'Location': 'New York', 'RegionIDn...
# 45  {'id': 89, 'Location': 'California', 'RegionID...
# 46  {'id': 129, 'Location': 'Oklahoma', 'RegionIDn...
# 47  {'id': 98, 'Location': 'Illinois', 'RegionIDne...
# 48  {'id': 121, 'Location': 'New York', 'RegionIDn...
# 49  {'id': 99, 'Location': 'Indiana', 'RegionIDnew...
#
# [1950 rows x 5 columns]

# %%
MTP_df_final.to_csv("raw_data.csv")
